# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pickle
import gensim
from gensim.models.ldamulticore import LdaMulticore
from gensim import corpora, models
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import pyLDAvis
import pyLDAvis.gensim_models

from nltk.corpus import stopwords
import string
from nltk.stem.wordnet import WordNetLemmatizer

import warnings
warnings.simplefilter('ignore')
from itertools import chain
from sklearn.feature_extraction.text import CountVectorizer
from tqdm import tqdm
from tqdm.auto import tqdm

# %%
# Process Data for LDA
df = pd.read_csv("./doc.csv")
df['Year']= pd.to_datetime(df['Year'])
df.set_index('Year')
def strip_intro(text):
    i = text.find("By unanimous vote,")
    if(i == -1):
        i = text.find("At the start")
        if(i == -1):
            return text
    return text[i:]
df
stop = set(stopwords.words('english'))
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()

def clean(text):
    stop_free = ' '.join([word for word in text.lower().split() if word not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = ' '.join([lemma.lemmatize(word) for word in punc_free.split()])
    return normalized.split()

ldf = pd.DataFrame()
ldf['statement_clean'] = df['Statement'].apply(strip_intro)
ldf = ldf[ldf['statement_clean'].str.startswith(('By unanimous','At the start'))]
ldf['text_clean'] = ldf['statement_clean'].apply(clean)
ldf
# Out:
#                                        statement_clean  \
# 0    By unanimous vote, the Committee ratified the ...
# 1    By unanimous vote, the minutes for the meeting...
# 2    By unanimous vote, the minutes for the meeting...
# 3    By unanimous vote, the Committee elected the f...
# 4    By unanimous vote, the minutes for the meeting...
# ..                                                 ...
# 220  By unanimous vote, the following officers of t...
# 221  By unanimous vote, the Committee ratified the ...
# 222  By unanimous vote, the Committee voted to appr...
# 223  By unanimous vote, the following officers of t...
# 224  By unanimous vote, the Committee ratified the ...
#
#                                             text_clean
# 0    [unanimous, vote, committee, ratified, desk, d...
# 1    [unanimous, vote, minute, meeting, federal, op...
# 2    [unanimous, vote, minute, meeting, federal, op...
# 3    [unanimous, vote, committee, elected, followin...
# 4    [unanimous, vote, minute, meeting, federal, op...
# ..                                                 ...
# 220  [unanimous, vote, following, officer, committe...
# 221  [unanimous, vote, committee, ratified, desk, d...
# 222  [unanimous, vote, committee, voted, approve, r...
# 223  [unanimous, vote, following, officer, committe...
# 224  [unanimous, vote, committee, ratified, desk, d...
#
# [224 rows x 2 columns]

# %%
dictionary = corpora.Dictionary(ldf['text_clean']) # Dictionary
doc_term_matrix = [dictionary.doc2bow(doc) for doc in ldf['text_clean'] ] # Corpus
lda = gensim.models.ldamodel.LdaModel

# %%
num_topics=7
# %time ldamodel = lda(doc_term_matrix,num_topics=num_topics,id2word=dictionary,passes=50,minimum_probability=0)
lda_display = pyLDAvis.gensim_models.prepare(ldamodel, doc_term_matrix, dictionary, sort_topics=False, mds='mmds')
pyLDAvis.save_html(lda_display, 'lda.html')
pyLDAvis.display(lda_display)
# Out:
# CPU times: user 54.7 s, sys: 0 ns, total: 54.7 s
# Wall time: 54.7 s
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el7481404920505284003662528625"></div>
# <script type="text/javascript">
#
# var ldavis_el7481404920505284003662528625_data = {"mdsDat": {"x": [-0.03322666006051712, -0.03633206351033901, -0.05904524073497086, -0.08617183520223305, 0.10169079598101495, 0.05944375589804894, 0.05364124762899617], "y": [0.022657028190595153, -0.12371688796345784, -0.02161317722480854, 0.06408098697488672, -0.05325658699183687, -0.008740139667461379, 0.12058877668208273], "topics": [1, 2, 3, 4, 5, 6, 7], "cluster": [1, 1, 1, 1, 1, 1, 1], "Freq": [15.31162396932757, 11.164339139418919, 17.67766692917948, 7.475700119520889, 4.583555159160299, 27.603635074679367, 16.183479608713476]}, "tinfo": {"Term": ["market", "participant", "financial", "bank", "member", "foreign", "federal", "currency", "economic", "shall", "would", "m3", "committee", "system", "operation", "risk", "rate", "range", "condition", "1998", "inflation", "fund", "september", "price", "december", "economy", "easing", "reserve", "open", "business", "revelation", "terrorism", "conveyed", "tragedy", "economy\u2019s", "discipline", "bleak", "overinvestments", "irregularity", "governed", "lowerquality", "restored", "mayjune", "protectionism", "deficiency", "timewas", "researchacross", "budgetary", "formwhether", "contemplating", "boththeir", "chainlinked", "prospectsfor", "july\u2019s", "marketsmight", "specter", "gathering", "elapse", "weakerthan", "war", "definitive", "iraq", "counterweight", "entrenched", "predominant", "unwelcome", "concurrently", "underutilized", "globalization", "identical", "13", "olson", "extraction", "bies", "reinhart", "vincent", "plausible", "2003", "passage", "incentive", "disinflation", "governance", "santomero", "highpriced", "impetus", "r", "tax", "2002", "margin", "disrupted", "bernanke", "geopolitical", "strengthening", "stimulus", "134", "recovery", "low", "spending", "messrs", "member", "business", "economic", "fiscal", "outlook", "accommodative", "capital", "statement", "would", "risk", "economy", "policy", "next", "activity", "inventory", "sale", "quarter", "committee", "market", "consumer", "continued", "level", "growth", "price", "inflation", "investment", "federal", "meeting", "period", "rate", "remained", "expansion", "recent", "condition", "year", "2007", "mandate", "normalization", "gross", "2006", "taf", "mb", "12month", "surveybased", "cre", "2019", "michigan", "2010", "2008", "2016", "2017", "2018", "reinvesting", "2011", "2014", "2015", "leveraged", "rrp", "card", "expects", "statutory", "2012", "anticipates", "sloos", "2013", "2009", "0", "al\u00adthough", "cmb", "participant", "medium", "desk", "judged", "path", "loan", "accommodation", "couple", "mortgagebacked", "policymakers", "reading", "sheet", "fomc", "real", "target", "credit", "inflation", "longerrun", "purchase", "survey", "pce", "commercial", "noted", "rate", "staff", "security", "market", "committee", "economic", "yield", "policy", "federal", "price", "continued", "remained", "expectation", "pace", "condition", "financial", "unemployment", "labor", "increase", "quarter", "would", "recent", "fund", "period", "growth", "percent", "outlook", "meeting", "year", "level", "consumer", "risk", "century", "recess", "catch", "chaired", "financialconditions", "encounter", "living", "interacting", "readjust", "reelected", "mid1999", "valve", "satisfy", "balanceofrisks", "burgeoning", "existed", "aggregative", "productionand", "aggregated", "aheadfrom", "recalibrate", "electrical", "inventorycorrection", "underway", "compensated", "interrelated", "reevaluation", "overestimated", "downshifting", "cancelled", "convened", "135", "612", "advisable", "eight", "onehalf", "frequent", "y2k", "paydown", "taut", "41", "abstracting", "pending", "2000", "januaryfebruary", "stringent", "forceful", "wake", "exerted", "consider", "date", "considering", "weighted", "today", "productivity", "interval", "tightening", "conference", "demand", "weakening", "mainly", "sentence", "point", "price", "core", "rising", "growth", "expansion", "acceleration", "twelve", "pressure", "future", "highe ...

# %%
# THIS TAKES FOREVER SO ONLY RUN IF YOU HAVE TO (RECOMMENDED NUM OF TOPICS IS 7)
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = lda(corpus,num_topics=num_topics,id2word=dictionary,passes=50,minimum_probability=0)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values
model_list, coherence_values = compute_coherence_values(dictionary=dictionary, corpus=doc_term_matrix, texts=list(ldf['text_clean']), start=2, limit=10, step=1)
limit=10; start=2; step=1;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
optimal_model = ldamodel
def format_topics_sentences(ldamodel, corpus, texts):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model, corpus=doc_term_matrix, texts=ldf['statement_clean'].reset_index()['statement_clean'])

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic # Dominant Topic per document
# Out:
#      Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0              0             1.0              0.9811
# 1              1             5.0              0.6556
# 2              2             5.0              0.6974
# 3              3             6.0              0.5710
# 4              4             5.0              0.6150
# ..           ...             ...                 ...
# 219          219             1.0              0.6418
# 220          220             1.0              0.7964
# 221          221             1.0              0.8098
# 222          222             1.0              0.5998
# 223          223             1.0              0.7793
#
#                                               Keywords  \
# 0    inflation, rate, market, committee, participan...
# 1    growth, committee, price, rate, range, market,...
# 2    growth, committee, price, rate, range, market,...
# 3    committee, foreign, market, currency, federal,...
# 4    growth, committee, price, rate, range, market,...
# ..                                                 ...
# 219  inflation, rate, market, committee, participan...
# 220  inflation, rate, market, committee, participan...
# 221  inflation, rate, market, committee, participan...
# 222  inflation, rate, market, committee, participan...
# 223  inflation, rate, market, committee, participan...
#
#                                                   Text
# 0    By unanimous vote, the Committee ratified the ...
# 1    By unanimous vote, the minutes for the meeting...
# 2    By unanimous vote, the minutes for the meeting...
# 3    By unanimous vote, the Committee elected the f...
# 4    By unanimous vote, the minutes for the meeting...
# ..                                                 ...
# 219  By unanimous vote, the following officers of t...
# 220  By unanimous vote, the Committee ratified the ...
# 221  By unanimous vote, the Committee voted to appr...
# 222  By unanimous vote, the following officers of t...
# 223  By unanimous vote, the Committee ratified the ...
#
# [224 rows x 5 columns]

# %%
sent_topics_sorteddf = pd.DataFrame()

sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf = pd.concat([sent_topics_sorteddf, 
                                             grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]

# Show
sent_topics_sorteddf # Top Text Per Topic
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0        0.0              0.9974
# 1        1.0              0.9997
# 2        2.0              0.9994
# 3        3.0              0.9988
# 4        4.0              0.9997
# 5        5.0              0.9989
# 6        6.0              0.8171
#
#                                             Keywords  \
# 0  member, economic, would, committee, market, gr...
# 1  inflation, rate, market, committee, participan...
# 2  price, growth, member, market, committee, infl...
# 3  member, economic, would, market, committee, ec...
# 4  market, financial, committee, price, federal, ...
# 5  growth, committee, price, rate, range, market,...
# 6  committee, foreign, market, currency, federal,...
#
#                                                 Text
# 0  By unanimous vote, the minutes of the meeting ...
# 1  By unanimous vote, the Committee ratified the ...
# 2  By unanimous vote, the minutes of the meeting ...
# 3  By unanimous vote, the minutes of the meeting ...
# 4  By unanimous vote, the minutes of the meeting ...
# 5  By unanimous vote, the Committee  ratified the...
# 6  By unanimous vote, the following officers of t...
